# %%
import numpy as np  
import matplotlib.pyplot as plt
import pandas as pd 

 #set the dataset
data= pd.read_csv('heart_Disease.csv')
data
# Out:
#       age  sex   cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63.0  1.0  3.0     145.0   233  1.0      0.0    150.0    0.0      2.3
# 1    37.0  NaN  2.0     130.0   250  0.0      1.0    187.0    0.0      3.5
# 2    41.0  0.0  1.0     130.0   204  0.0      0.0    172.0    0.0      1.4
# 3    56.0  1.0  1.0     120.0   236  0.0      1.0    178.0    0.0      0.8
# 4    57.0  0.0  0.0     120.0   354  0.0      1.0    163.0    1.0      0.6
# ..    ...  ...  ...       ...   ...  ...      ...      ...    ...      ...
# 298  57.0  0.0  NaN     140.0   241  0.0      1.0    123.0    1.0      0.2
# 299  45.0  1.0  3.0     110.0   264  0.0      1.0    132.0    0.0      1.2
# 300  68.0  1.0  0.0     144.0   193  1.0      1.0    141.0    0.0      3.4
# 301  57.0  1.0  0.0     130.0   131  0.0      1.0    115.0    1.0      1.2
# 302  57.0  0.0  1.0     130.0   236  0.0      0.0    174.0    0.0      0.0
#
#      slope   ca  thal  target
# 0      0.0  0.0   1.0     1.0
# 1      0.0  NaN   2.0     1.0
# 2      2.0  0.0   2.0     1.0
# 3      2.0  0.0   2.0     1.0
# 4      2.0  0.0   2.0     1.0
# ..     ...  ...   ...     ...
# 298    1.0  0.0   NaN     0.0
# 299    1.0  0.0   3.0     0.0
# 300    1.0  2.0   3.0     0.0
# 301    1.0  1.0   3.0     0.0
# 302    1.0  1.0   2.0     0.0
#
# [303 rows x 14 columns]

# %%
data.head(10)
# Out:
#     age  sex   cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  63.0  1.0  3.0     145.0   233  1.0      0.0    150.0    0.0      2.3
# 1  37.0  NaN  2.0     130.0   250  0.0      1.0    187.0    0.0      3.5
# 2  41.0  0.0  1.0     130.0   204  0.0      0.0    172.0    0.0      1.4
# 3  56.0  1.0  1.0     120.0   236  0.0      1.0    178.0    0.0      0.8
# 4  57.0  0.0  0.0     120.0   354  0.0      1.0    163.0    1.0      0.6
# 5  57.0  1.0  0.0     140.0   192  0.0      1.0    148.0    NaN      0.4
# 6  56.0  0.0  1.0     140.0   294  0.0      0.0    153.0    0.0      1.3
# 7   NaN  1.0  1.0     120.0   263  0.0      NaN    173.0    0.0      NaN
# 8  52.0  1.0  2.0     172.0   199  1.0      1.0    162.0    0.0      0.5
# 9  57.0  NaN  2.0     150.0   168  0.0      1.0    174.0    0.0      1.6
#
#    slope   ca  thal  target
# 0    0.0  0.0   1.0     1.0
# 1    0.0  NaN   2.0     1.0
# 2    2.0  0.0   2.0     1.0
# 3    2.0  0.0   2.0     1.0
# 4    2.0  0.0   2.0     1.0
# 5    1.0  0.0   1.0     1.0
# 6    1.0  0.0   2.0     1.0
# 7    2.0  0.0   3.0     1.0
# 8    2.0  0.0   3.0     1.0
# 9    2.0  0.0   2.0     1.0

# %%
data.tail(10)
# Out:
#       age  sex   cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 293  67.0  1.0  2.0     152.0   212  0.0      0.0    150.0    0.0      0.8
# 294  44.0  1.0  0.0     120.0   169  0.0      1.0    144.0    1.0      2.8
# 295  63.0  1.0  0.0     140.0   187  0.0      0.0    144.0    1.0      4.0
# 296  63.0  0.0  0.0     124.0   197  0.0      1.0    136.0    1.0      0.0
# 297  59.0  1.0  0.0     164.0   176  NaN      0.0     90.0    0.0      1.0
# 298  57.0  0.0  NaN     140.0   241  0.0      1.0    123.0    1.0      0.2
# 299  45.0  1.0  3.0     110.0   264  0.0      1.0    132.0    0.0      1.2
# 300  68.0  1.0  0.0     144.0   193  1.0      1.0    141.0    0.0      3.4
# 301  57.0  1.0  0.0     130.0   131  0.0      1.0    115.0    1.0      1.2
# 302  57.0  0.0  1.0     130.0   236  0.0      0.0    174.0    0.0      0.0
#
#      slope   ca  thal  target
# 293    1.0  0.0   3.0     0.0
# 294    0.0  0.0   1.0     NaN
# 295    2.0  2.0   3.0     0.0
# 296    1.0  0.0   2.0     0.0
# 297    NaN  2.0   1.0     0.0
# 298    1.0  0.0   NaN     0.0
# 299    1.0  0.0   3.0     0.0
# 300    1.0  2.0   3.0     0.0
# 301    1.0  1.0   3.0     0.0
# 302    1.0  1.0   2.0     0.0

# %%
data.dtypes
# Out:
# age         float64
# sex         float64
# cp          float64
# trestbps    float64
# chol          int64
# fbs         float64
# restecg     float64
# thalach     float64
# exang       float64
# oldpeak     float64
# slope       float64
# ca          float64
# thal        float64
# target      float64
# dtype: object

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
data.size
# Out:
# 4242

# %% [markdown]
# 1 in target columns mean the patient has heart disease, 0 means he does not have heart disease

# %%
# 1 in target columns mean the patient has heart disease, 0 means he does not have heart disease
data["target"].value_counts()
# Out:
# 1.0    165
# 0.0    136
# Name: target, dtype: int64

# %%
data.shape
# Out:
# (303, 14)

# %%
data.isnull().sum()
# Out:
# age         2
# sex         4
# cp          4
# trestbps    3
# chol        0
# fbs         2
# restecg     1
# thalach     1
# exang       2
# oldpeak     2
# slope       2
# ca          2
# thal        3
# target      2
# dtype: int64

# %%
data.describe().T
# Out:
#           count        mean        std    min     25%    50%    75%    max
# age       301.0   54.368771   9.075621   29.0   48.00   55.0   61.0   77.0
# sex       299.0    0.682274   0.466373    0.0    0.00    1.0    1.0    1.0
# cp        299.0    0.973244   1.032664    0.0    0.00    1.0    2.0    3.0
# trestbps  300.0  131.423333  17.451053   94.0  120.00  130.0  140.0  200.0
# chol      303.0  246.264026  51.830751  126.0  211.00  240.0  274.5  564.0
# fbs       301.0    0.146179   0.353874    0.0    0.00    0.0    0.0    1.0
# restecg   302.0    0.526490   0.526027    0.0    0.00    1.0    1.0    2.0
# thalach   302.0  149.576159  22.910033   71.0  133.25  152.5  166.0  202.0
# exang     301.0    0.328904   0.470597    0.0    0.00    0.0    1.0    1.0
# oldpeak   301.0    1.044518   1.163104    0.0    0.00    0.8    1.6    6.2
# slope     301.0    1.405316   0.612513    0.0    1.00    1.0    2.0    2.0
# ca        301.0    0.734219   1.024268    0.0    0.00    0.0    1.0    4.0
# thal      300.0    2.316667   0.597981    0.0    2.00    2.0    3.0    3.0
# target    301.0    0.548173   0.498503    0.0    0.00    1.0    1.0    1.0

# %%
heart_data = data.copy(deep = True)

heart_data[['age','sex','cp','trestbps','fbs', 'restecg','thalach','exang','oldpeak', 'slope', 'ca','thal', 'target']] = heart_data[['age','sex','cp','trestbps','fbs', 'restecg','thalach','exang','oldpeak', 'slope', 'ca','thal', 'target']].replace(0,np.NaN)

## showing the count of Nans
print(heart_data.isnull().sum())
# Out:
# age           2
# sex          99
# cp          144
# trestbps      3
# chol          0
# fbs         259
# restecg     148
# thalach       1
# exang       204
# oldpeak     100
# slope        22
# ca          175
# thal          4
# target      138
# dtype: int64

# %%
p = data.hist(figsize = (30,30))

# %%
##handle the null data or values with .mean()

heart_data['age'].fillna(heart_data['age'].mean(), inplace = True) 
heart_data['sex'].fillna(heart_data['sex'].mean(), inplace = True) 
heart_data['cp'].fillna(heart_data['cp'].mean(), inplace = True) 
heart_data['trestbps'].fillna(heart_data['trestbps'].mean(), inplace = True)
heart_data['fbs'].fillna(heart_data['fbs'].mean(), inplace = True)
heart_data['restecg'].fillna(heart_data['restecg'].mean(), inplace = True)
heart_data['thalach'].fillna(heart_data['thalach'].mean(), inplace = True)
heart_data['exang'].fillna(heart_data['exang'].mean(), inplace = True)
heart_data['oldpeak'].fillna(heart_data['oldpeak'].mean(), inplace = True)
heart_data['slope'].fillna(heart_data['slope'].mean(), inplace = True)
heart_data['ca'].fillna(heart_data['ca'].mean(), inplace = True)
heart_data['thal'].fillna(heart_data['thal'].mean(), inplace = True)
heart_data['target'].fillna(heart_data['target'].mean(), inplace = True)

# %%
heart_data
# Out:
#       age  sex        cp  trestbps  chol  fbs   restecg  thalach  exang  \
# 0    63.0  1.0  3.000000     145.0   233  1.0  1.025806    150.0    1.0
# 1    37.0  1.0  2.000000     130.0   250  1.0  1.000000    187.0    1.0
# 2    41.0  1.0  1.000000     130.0   204  1.0  1.025806    172.0    1.0
# 3    56.0  1.0  1.000000     120.0   236  1.0  1.000000    178.0    1.0
# 4    57.0  1.0  1.830189     120.0   354  1.0  1.000000    163.0    1.0
# ..    ...  ...       ...       ...   ...  ...       ...      ...    ...
# 298  57.0  1.0  1.830189     140.0   241  1.0  1.000000    123.0    1.0
# 299  45.0  1.0  3.000000     110.0   264  1.0  1.000000    132.0    1.0
# 300  68.0  1.0  1.830189     144.0   193  1.0  1.000000    141.0    1.0
# 301  57.0  1.0  1.830189     130.0   131  1.0  1.000000    115.0    1.0
# 302  57.0  1.0  1.000000     130.0   236  1.0  1.025806    174.0    1.0
#
#       oldpeak     slope        ca      thal  target
# 0    2.300000  1.505338  1.726562  1.000000     1.0
# 1    3.500000  1.505338  1.726562  2.000000     1.0
# 2    1.400000  2.000000  1.726562  2.000000     1.0
# 3    0.800000  2.000000  1.726562  2.000000     1.0
# 4    0.600000  2.000000  1.726562  2.000000     1.0
# ..        ...       ...       ...       ...     ...
# 298  0.200000  1.000000  1.726562  2.324415     1.0
# 299  1.200000  1.000000  1.726562  3.000000     1.0
# 300  3.400000  1.000000  2.000000  3.000000     1.0
# 301  1.200000  1.000000  1.000000  3.000000     1.0
# 302  1.548768  1.000000  1.000000  2.000000     1.0
#
# [303 rows x 14 columns]

# %%
p = data.hist(figsize = (30,30))

# %%
##Splitting the data into test and train sets
from sklearn.model_selection import train_test_split #training and testing data split


X=data[['age','sex','cp','trestbps','fbs', 'restecg','thalach','exang','oldpeak', 'slope', 'ca','thal']]
y=data["target"]

train_X,test_X,train_Y,test_Y=train_test_split(X,y,test_size=0.3,random_state=0)

train_X,val_X,train_Y,val_Y=train_test_split(train_X,train_Y,test_size=0.3,random_state=0)

len(train_X), len(train_Y), len(test_X), len(test_Y)
# Out:
# (148, 148, 91, 91)

# %%
## .fillna(0) : to replace the NaN with 0 becuse without ths methos the dessition tree and KNN will not work 
train_X.fillna(0)
# Out:
#       age  sex   cp  trestbps  fbs  restecg  thalach  exang  oldpeak  slope  \
# 205  52.0  1.0  0.0     128.0  0.0      1.0    161.0    1.0      0.0    2.0
# 95   53.0  1.0  0.0     142.0  0.0      0.0    111.0    1.0      0.0    2.0
# 120  64.0  0.0  0.0     130.0  0.0      1.0    122.0    0.0      2.0    1.0
# 176  60.0  1.0  0.0     117.0  1.0      1.0    160.0    1.0      1.4    2.0
# 60   71.0  0.0  2.0     110.0  1.0      0.0    130.0    0.0      0.0    2.0
# ..    ...  ...  ...       ...  ...      ...      ...    ...      ...    ...
# 268  54.0  1.0  0.0     122.0  0.0      0.0    116.0    1.0      3.2    1.0
# 165  67.0  1.0  0.0     160.0  0.0      0.0    108.0    1.0      1.5    1.0
# 48   53.0  0.0  2.0     128.0  0.0      0.0    115.0    0.0      0.0    2.0
# 295  63.0  1.0  0.0     140.0  0.0      0.0    144.0    1.0      4.0    2.0
# 163  38.0  1.0  2.0     138.0  0.0      1.0    173.0    0.0      0.0    2.0
#
#       ca  thal
# 205  1.0   3.0
# 95   0.0   3.0
# 120  2.0   2.0
# 176  2.0   3.0
# 60   1.0   2.0
# ..   ...   ...
# 268  2.0   2.0
# 165  3.0   2.0
# 48   0.0   0.0
# 295  2.0   3.0
# 163  4.0   2.0
#
# [148 rows x 12 columns]

# %%
train_Y.fillna(0)
# Out:
# 205    0.0
# 95     1.0
# 120    1.0
# 176    0.0
# 60     1.0
#       ...
# 268    0.0
# 165    0.0
# 48     1.0
# 295    0.0
# 163    1.0
# Name: target, Length: 148, dtype: float64

# %%
#the train data
train_X.head()
# Out:
#       age  sex   cp  trestbps  fbs  restecg  thalach  exang  oldpeak  slope  \
# 205  52.0  1.0  0.0     128.0  0.0      1.0    161.0    1.0      0.0    2.0
# 95   53.0  1.0  0.0     142.0  0.0      0.0    111.0    1.0      0.0    2.0
# 120  64.0  0.0  0.0     130.0  0.0      1.0    122.0    0.0      2.0    1.0
# 176  60.0  1.0  0.0     117.0  1.0      1.0    160.0    1.0      1.4    2.0
# 60   71.0  0.0  2.0     110.0  1.0      0.0    130.0    0.0      0.0    2.0
#
#       ca  thal
# 205  1.0   3.0
# 95   0.0   3.0
# 120  2.0   2.0
# 176  2.0   3.0
# 60   1.0   2.0

# %%
#the train data 
train_Y.head()
# Out:
# 205    0.0
# 95     1.0
# 120    1.0
# 176    0.0
# 60     1.0
# Name: target, dtype: float64

# %%
test_Y.head()
# Out:
# 225    0.0
# 152    1.0
# 228    0.0
# 201    0.0
# 52     1.0
# Name: target, dtype: float64

# %%
test_X.head()
# Out:
#       age  sex   cp  trestbps  fbs  restecg  thalach  exang  oldpeak  slope  \
# 225  70.0  1.0  0.0     145.0  0.0      1.0    125.0    1.0      2.6    0.0
# 152  64.0  1.0  3.0     170.0  0.0      0.0    155.0    0.0      0.6    1.0
# 228  59.0  1.0  3.0     170.0  0.0      0.0    159.0    0.0      0.2    1.0
# 201  60.0  1.0  0.0     125.0  0.0      0.0    141.0    1.0      2.8    1.0
# 52   62.0  1.0  2.0     130.0  0.0      1.0    146.0    0.0      1.8    1.0
#
#       ca  thal
# 225  0.0   3.0
# 152  0.0   3.0
# 228  0.0   3.0
# 201  1.0   3.0
# 52   3.0   3.0

# %% [markdown]
# # Decision Tree Code

# %%
#Decision Tree

from sklearn.tree import DecisionTreeClassifier 
dt=DecisionTreeClassifier()

train_Y=train_Y.fillna(0)
train_X=train_X.fillna(0)
test_X=test_X.fillna(0)
test_Y=test_Y.fillna(0)

dt=dt.fit(train_X,train_Y)

# %%
heart_data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
#accuracy
# Predicting results using testing  data set

pred = dt.predict(test_X)

# Accuracy score
from sklearn.metrics import accuracy_score
accuracy_score(pred,test_Y)
# Out:
# 0.6813186813186813

# %%
#accuracy
# Predicting results using training data set
pred = dt.predict(train_X)
accuracy_score(pred,train_Y)
# Out:
# 1.0

# %%
# confusion_matrix
import seaborn as sns
sns.set()
from sklearn.metrics import confusion_matrix
from sklearn import metrics

print("\n")
y_pred = dt.predict(test_X)

cnf_matrix = metrics.confusion_matrix(test_Y, y_pred)

p = sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 19.049999999999997, 'Predicted label')

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, fbeta_score
def model_evaluation(test_Y, y_pred, model_name):
    acc = accuracy_score(test_Y, y_pred)
    prec = precision_score(test_Y, y_pred)
    rec = recall_score(test_Y, y_pred)
    f1 = f1_score(test_Y, y_pred)
    f2 = fbeta_score(test_Y, y_pred, beta = 2.0)

    results = pd.DataFrame([[model_name, acc, prec, rec, f1, f2]], 
                       columns = ["Model", "Accuracy", "Precision", "Recall",
                                 "F1 SCore", "F2 Score"])
    results = results.sort_values(["Precision", "Recall", "F2 Score"], ascending = False)
    return results

print("\n")

model_evaluation(test_Y, y_pred, "DecisionTree")
# Out:
#           Model  Accuracy  Precision    Recall  F1 SCore  F2 Score
# 0  DecisionTree  0.681319   0.673077  0.744681  0.707071  0.729167

# %%
from sklearn.metrics import classification_report
val_accuracy = accuracy_score(test_Y, y_pred)
print("\n")
print(f'Accuracy Validation for the Decision Tree is: {val_accuracy}')
print("\n")
target_names = ['no 0', 'yes 1']
print(classification_report(test_Y, y_pred, target_names=target_names))
print("\n")
# Out:
# Accuracy Validation for the Decision Tree is: 0.6813186813186813
#
#
#               precision    recall  f1-score   support
#
#         no 0       0.69      0.61      0.65        44
#        yes 1       0.67      0.74      0.71        47
#
#     accuracy                           0.68        91
#    macro avg       0.68      0.68      0.68        91
# weighted avg       0.68      0.68      0.68        91

# %%
from sklearn.metrics import auc, roc_auc_score, roc_curve, precision_recall_curve

# Decision Tree
modelTree=DecisionTreeClassifier()
modelTree.fit(train_X,train_Y)
y_pred_prob_Tree = modelTree.predict_proba(test_X)[:,1]
fpr_Tree, tpr_Tree, thresholds_Tree = roc_curve(test_Y, y_pred_prob_Tree)
roc_auc_Tree = auc(fpr_Tree, tpr_Tree)
precision_Tree, recall_Tree, th_Tree = precision_recall_curve(test_Y, y_pred_prob_Tree)

print("\n")

plt.plot([0, 1], [0, 1], 'k--')
 
plt.plot(fpr_Tree, tpr_Tree, label='Tree (area = %0.3f)' % roc_auc_Tree)

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC curves for DecisionTreeClassifier')
plt.legend(loc='best')
plt.show()
print("\n")

# %% [markdown]
# # KNN Code

# %%
from sklearn.neighbors import KNeighborsClassifier

train_scores = []
test_scores = []

for i in range(1,15):
    knn = KNeighborsClassifier(i)
    knn.fit(train_X,train_Y)
    train_scores.append(knn.score(train_X,train_Y))
    test_scores.append(knn.score(train_X,train_Y))

# %%
##accuracy
# Predicting results using testing  data set
pred = knn.predict(test_X)
accuracy_score(pred,test_Y)
# Out:
# 0.6483516483516484

# %%
# Running KNN for various values of n_neighbors and storing results
knn_r_acc = []
for i in range(1,17,1):
    knn = KNeighborsClassifier(n_neighbors=i)
    
    knn.fit(train_X,train_Y)
    
    test_score = knn.score(test_X, test_Y)
    train_score = knn.score(train_X, train_Y)
    
    knn_r_acc.append((i, test_score ,train_score))
df = pd.DataFrame(knn_r_acc , columns=['K','Accuracy Test Score','Accuracy Train Score'])
print("\n")
print(df)
print("\n")
# Out:
#      K  Accuracy Test Score  Accuracy Train Score
# 0    1             0.626374              1.000000
# 1    2             0.659341              0.797297
# 2    3             0.648352              0.817568
# 3    4             0.670330              0.783784
# 4    5             0.648352              0.770270
# 5    6             0.692308              0.722973
# 6    7             0.604396              0.729730
# 7    8             0.648352              0.695946
# 8    9             0.615385              0.729730
# 9   10             0.637363              0.736486
# 10  11             0.626374              0.743243
# 11  12             0.637363              0.736486
# 12  13             0.626374              0.729730
# 13  14             0.648352              0.709459
# 14  15             0.626374              0.716216
# 15  16             0.637363              0.722973

# %%
## score that comes from testing  
max_test_score = max(test_scores)
test_scores_ind = [i for i, v in enumerate(test_scores) if v == max_test_score]
print('Max test score {} % and k = {}'.format(max_test_score*100,list(map(lambda x: x+1, test_scores_ind))))
# Out:
# Max test score 100.0 % and k = [1]

# %%
##Visualizing KNN
plt.figure(figsize=(10,5))
p = sns.lineplot( train_scores,marker='*',label='Train Score')
p = sns.lineplot( test_scores,marker='o',label='Test Score')

# %%
#  confusion_matrix
import seaborn as sns
sns.set()
from sklearn.metrics import confusion_matrix
from sklearn import metrics
print("\n")
y_pred = knn.predict(test_X)
cnf_matrix = metrics.confusion_matrix(test_Y, y_pred)
p = sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 19.049999999999997, 'Predicted label')

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, fbeta_score
def model_evaluation(test_Y, y_pred, model_name):
    acc = accuracy_score(test_Y, y_pred)
    prec = precision_score(test_Y, y_pred)
    rec = recall_score(test_Y, y_pred)
    f1 = f1_score(test_Y, y_pred)
    f2 = fbeta_score(test_Y, y_pred, beta = 2.0)

    results = pd.DataFrame([[model_name, acc, prec, rec, f1, f2]], 
                       columns = ["Model", "Accuracy", "Precision", "Recall",
                                 "F1 SCore", "F2 Score"])
    results = results.sort_values(["Precision", "Recall", "F2 Score"], ascending = False)
    return results


print("\n")
model_evaluation(test_Y, y_pred, "KNN")
# Out:
#   Model  Accuracy  Precision    Recall  F1 SCore  F2 Score
# 0   KNN  0.637363      0.625  0.744681  0.679612  0.717213

# %%
from sklearn.metrics import classification_report
val_accuracy = accuracy_score(test_Y, y_pred)
print("\n")
print(f'Accuracy Validation for the KNN is: {val_accuracy}')
print("\n")
target_names = ['no 0', 'yes 1']
print(classification_report(test_Y, y_pred, target_names=target_names))
# Out:
# Accuracy Validation for the KNN is: 0.6373626373626373
#
#
#               precision    recall  f1-score   support
#
#         no 0       0.66      0.52      0.58        44
#        yes 1       0.62      0.74      0.68        47
#
#     accuracy                           0.64        91
#    macro avg       0.64      0.63      0.63        91
# weighted avg       0.64      0.64      0.63        91

# %%
knn_5 = KNeighborsClassifier(n_neighbors=7)

# fit the model to the training set
knn_5.fit(train_X,train_Y)

# predict on the test-set
y_pred_5 = knn_5.predict(test_X)

print('Model accuracy score with k=7: {0:0.4f}'. format(accuracy_score(test_Y, y_pred_5)))
# Out:
# Model accuracy score with k=7: 0.6044

# %%
from sklearn.metrics import auc, roc_auc_score, roc_curve, precision_recall_curve

# KNN
modelKNN = KNeighborsClassifier(n_neighbors=7)
modelKNN.fit(train_X,train_Y)

y_pred_prob_KNN = modelKNN.predict_proba(test_X)[:,1]
fpr_KNN, tpr_KNN, thresholds_KNN = roc_curve(test_Y, y_pred_prob_KNN)
roc_auc_KNN = auc(fpr_KNN, tpr_KNN)
precision_KNN, recall_KNN, th_KNN = precision_recall_curve(test_Y, y_pred_prob_KNN)

print("\n")
plt.plot([0, 1], [0, 1], 'k--')
 
plt.plot(fpr_KNN, tpr_KNN, label='KNN (area = %0.3f)' % roc_auc_KNN)

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC curves for KNN')
plt.legend(loc='best')
plt.show()
